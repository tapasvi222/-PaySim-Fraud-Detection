# %% [markdown]
# # **importing**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv('/content/PS_20174392719_1491204439457_log.csv',on_bad_lines='skip')
print(df)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1          1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2          1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3          1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4          1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 165434    12   PAYMENT    4149.07  C2001802076            0.0            0.00
# 165435    12   PAYMENT   20934.94   C150264052            0.0            0.00
# 165436    12  CASH_OUT  122832.41  C1327637933        23958.0            0.00
# 165437    12   CASH_IN  424626.95   C944569458        58972.0       483598.95
# 165438    12   PAYMENT   35864.56   C382841079        63909.0        28044.44
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0       M1979787155             0.0             0.0      0.0             0.0
# 1       M2044282225             0.0             0.0      0.0             0.0
# 2        C553264065             0.0             0.0      1.0             0.0
# 3         C38997010         21182.0             0.0      1.0             0.0
# 4       M1230701703             0.0             0.0      0.0             0.0
# ...             ...             ...             ...      ...             ...
# 165434  M1708280162             0.0             0.0      0.0             0.0
# 165435   M806755072             0.0             0.0      0.0             0.0
# 165436   C475670359         11507.0             0.0      0.0             0.0
# 165437   C929611695             0.0             0.0      0.0             0.0
# 165438            M             NaN             NaN      NaN             NaN
#
# [165439 rows x 11 columns]

# %%
df.head(5)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
df.tail(5)
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 165434    12   PAYMENT    4149.07  C2001802076            0.0            0.00
# 165435    12   PAYMENT   20934.94   C150264052            0.0            0.00
# 165436    12  CASH_OUT  122832.41  C1327637933        23958.0            0.00
# 165437    12   CASH_IN  424626.95   C944569458        58972.0       483598.95
# 165438    12   PAYMENT   35864.56   C382841079        63909.0        28044.44
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 165434  M1708280162             0.0             0.0      0.0             0.0
# 165435   M806755072             0.0             0.0      0.0             0.0
# 165436   C475670359         11507.0             0.0      0.0             0.0
# 165437   C929611695             0.0             0.0      0.0             0.0
# 165438            M             NaN             NaN      NaN             NaN

# %%
df.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  165439.000000  1.654390e+05   1.654390e+05    1.654390e+05
# mean        9.553715  1.793496e+05   8.862403e+05    9.031748e+05
# std         1.967747  3.360318e+05   2.812176e+06    2.848990e+06
# min         1.000000  3.200000e-01   0.000000e+00    0.000000e+00
# 25%         9.000000  1.141030e+04   0.000000e+00    0.000000e+00
# 50%        10.000000  6.376490e+04   1.951200e+04    0.000000e+00
# 75%        11.000000  2.248438e+05   1.901025e+05    2.227964e+05
# max        12.000000  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest        isFraud  isFlaggedFraud
# count    1.654380e+05    1.654380e+05  165438.000000        165438.0
# mean     9.229948e+05    1.185652e+06       0.000804             0.0
# std      2.380862e+06    2.690358e+06       0.028342             0.0
# min      0.000000e+00    0.000000e+00       0.000000             0.0
# 25%      0.000000e+00    0.000000e+00       0.000000             0.0
# 50%      3.956590e+04    1.070278e+05       0.000000             0.0
# 75%      7.106599e+05    1.144234e+06       0.000000             0.0
# max      3.894623e+07    3.904248e+07       1.000000             0.0

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
print(df.describe())
# Out:
#            step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count 165439.00   165439.00      165439.00       165439.00       165438.00
# mean       9.55   179349.60      886240.28       903174.81       922994.79
# std        1.97   336031.82     2812175.82      2848989.57      2380861.61
# min        1.00        0.32           0.00            0.00            0.00
# 25%        9.00    11410.30           0.00            0.00            0.00
# 50%       10.00    63764.90       19512.00            0.00        39565.90
# 75%       11.00   224843.83      190102.51       222796.38       710659.90
# max       12.00 10000000.00    38939424.03     38946233.02     38946233.02
#
#        newbalanceDest   isFraud  isFlaggedFraud
# count       165438.00 165438.00       165438.00
# mean       1185651.52      0.00            0.00
# std        2690357.90      0.03            0.00
# min              0.00      0.00            0.00
# 25%              0.00      0.00            0.00
# 50%         107027.80      0.00            0.00
# 75%        1144234.28      0.00            0.00
# max       39042481.25      1.00            0.00

# %% [markdown]
# # **checking missing values**

# %%
df.isnull()
# Out:
#          step   type  amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       False  False   False     False          False           False
# 1       False  False   False     False          False           False
# 2       False  False   False     False          False           False
# 3       False  False   False     False          False           False
# 4       False  False   False     False          False           False
# ...       ...    ...     ...       ...            ...             ...
# 165434  False  False   False     False          False           False
# 165435  False  False   False     False          False           False
# 165436  False  False   False     False          False           False
# 165437  False  False   False     False          False           False
# 165438  False  False   False     False          False           False
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0          False           False           False    False           False
# 1          False           False           False    False           False
# 2          False           False           False    False           False
# 3          False           False           False    False           False
# 4          False           False           False    False           False
# ...          ...             ...             ...      ...             ...
# 165434     False           False           False    False           False
# 165435     False           False           False    False           False
# 165436     False           False           False    False           False
# 165437     False           False           False    False           False
# 165438     False            True            True     True            True
#
# [165439 rows x 11 columns]

# %% [markdown]
# **checking
#  missing values**

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    1
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %% [markdown]
# # **droping missing values**

# %%
df.dropna(inplace=True)
print(df)
# Out:
#         step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1          1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2          1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3          1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4          1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# ...      ...       ...       ...          ...            ...             ...
# 165433    12   PAYMENT   7724.77   C226232058        2709.00            0.00
# 165434    12   PAYMENT   4149.07  C2001802076           0.00            0.00
# 165435    12   PAYMENT  20934.94   C150264052           0.00            0.00
# 165436    12  CASH_OUT 122832.41  C1327637933       23958.00            0.00
# 165437    12   CASH_IN 424626.95   C944569458       58972.00       483598.95
#
#            nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0       M1979787155            0.00            0.00     0.00            0.00
# 1       M2044282225            0.00            0.00     0.00            0.00
# 2        C553264065            0.00            0.00     1.00            0.00
# 3         C38997010        21182.00            0.00     1.00            0.00
# 4       M1230701703            0.00            0.00     0.00            0.00
# ...             ...             ...             ...      ...             ...
# 165433  M1419610354            0.00            0.00     0.00            0.00
# 165434  M1708280162            0.00            0.00     0.00            0.00
# 165435   M806755072            0.00            0.00     0.00            0.00
# 165436   C475670359        11507.00            0.00     0.00            0.00
# 165437   C929611695            0.00            0.00     0.00            0.00
#
# [165438 rows x 11 columns]

# %% [markdown]
# # **filling missing values**

# %%
df['amount'] = df['amount'].fillna(df['amount'].median())
df['oldbalanceOrg']=df['oldbalanceOrg'].fillna(df['oldbalanceOrg'].median())
df['newbalanceOrig']=df['newbalanceOrig'].fillna(df['newbalanceOrig'].median())
df['type']=df['type'].fillna(df['type'].mode()[0])
df['nameOrig']=df['nameOrig'].fillna(df['nameOrig'].mode()[0])
df['isFraud']=df['isFraud'].fillna(df['isFraud'].mode()[0])

# %%
df.head(10)
# Out:
#    step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT  9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT  1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER   181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT   181.00   C840083671         181.00            0.00
# 4     1   PAYMENT 11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT  7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT  7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT  7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT  4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT  5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155            0.00            0.00     0.00            0.00
# 1  M2044282225            0.00            0.00     0.00            0.00
# 2   C553264065            0.00            0.00     1.00            0.00
# 3    C38997010        21182.00            0.00     1.00            0.00
# 4  M1230701703            0.00            0.00     0.00            0.00
# 5   M573487274            0.00            0.00     0.00            0.00
# 6   M408069119            0.00            0.00     0.00            0.00
# 7   M633326333            0.00            0.00     0.00            0.00
# 8  M1176932104            0.00            0.00     0.00            0.00
# 9   C195600860        41898.00        40348.79     0.00            0.00

# %%
df.shape
# Out:
# (165438, 11)

# %% [markdown]
# # **Equalizing rows**

# %%
df['newbalanceOrig'] = df['oldbalanceOrg'] - df['amount']
df.loc[df['type'].isin(['TRANSFER', 'CASH_OUT']), 'newbalanceDest'] = df['oldbalanceDest'] + df['amount']
df.to_csv("corrected_file.csv", index=False)
print("Dataset corrected and saved as 'corrected_file.csv'")
# Out:
# Dataset corrected and saved as 'corrected_file.csv'

# %%
df['isFraud'].sum()
# Out:
# 133.0

# %% [markdown]
# # **checking data types**

# %%
a = df['type'].value_counts()
print(a)
# Out:
# type
# PAYMENT     62237
# CASH_OUT    54182
# CASH_IN     33762
# TRANSFER    13779
# DEBIT        1478
# Name: count, dtype: int64

# %%
df['type'] = df['type'].replace('CASH_I', 'CASH_IN')

# %%
print(a)
# Out:
# type
# PAYMENT     62237
# CASH_OUT    54182
# CASH_IN     33762
# TRANSFER    13779
# DEBIT        1478
# Name: count, dtype: int64

# %%
print(df['type'].unique())
# Out:
# ['PAYMENT' 'TRANSFER' 'CASH_OUT' 'DEBIT' 'CASH_IN']

# %%
print(df['isFraud'].unique())
# Out:
# [0. 1.]

# %%
df['isFraud'].fillna(0)
# Out:
# 0        0.00
# 1        0.00
# 2        1.00
# 3        1.00
# 4        0.00
#          ...
# 165433   0.00
# 165434   0.00
# 165435   0.00
# 165436   0.00
# 165437   0.00
# Name: isFraud, Length: 165438, dtype: float64

# %%
df.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud           float64
# isFlaggedFraud    float64
# dtype: object

# %%
print(df['isFraud'].isnull().sum())
print(df['isFlaggedFraud'].isnull().sum())
# Out:
# 0
# 0

# %%
df['isFraud'].fillna(0)
df['isFlaggedFraud'].fillna(0)
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
#          ...
# 165433   0.00
# 165434   0.00
# 165435   0.00
# 165436   0.00
# 165437   0.00
# Name: isFlaggedFraud, Length: 165438, dtype: float64

# %%
df['isFraud'].isnull().sum()
df['isFlaggedFraud'].isnull().sum()
# Out:
# 0

# %%
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 165433    False
# 165434    False
# 165435    False
# 165436    False
# 165437    False
# Length: 165438, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165438 entries, 0 to 165437
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            165438 non-null  int64
#  1   type            165438 non-null  object
#  2   amount          165438 non-null  float64
#  3   nameOrig        165438 non-null  object
#  4   oldbalanceOrg   165438 non-null  float64
#  5   newbalanceOrig  165438 non-null  float64
#  6   nameDest        165438 non-null  object
#  7   oldbalanceDest  165438 non-null  float64
#  8   newbalanceDest  165438 non-null  float64
#  9   isFraud         165438 non-null  float64
#  10  isFlaggedFraud  165438 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 19.2+ MB

# %%
df.describe()
# Out:
#            step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count 165438.00   165438.00      165438.00       165438.00       165438.00
# mean       9.55   179350.47      886245.25       706894.78       922994.79
# std        1.97   336032.65     2812183.59      2838302.54      2380861.61
# min        1.00        0.32           0.00     -6388051.27            0.00
# 25%        9.00    11410.16           0.00      -149855.77            0.00
# 50%       10.00    63765.80       19511.00        -8784.12        39565.90
# 75%       11.00   224848.46      190112.30       108234.89       710659.90
# max       12.00 10000000.00    38939424.03     38932615.04     38946233.02
#
#        newbalanceDest   isFraud  isFlaggedFraud
# count       165438.00 165438.00       165438.00
# mean       1077413.97      0.00            0.00
# std        2522704.22      0.03            0.00
# min              0.00      0.00            0.00
# 25%              0.00      0.00            0.00
# 50%         146509.27      0.00            0.00
# 75%         976301.69      0.00            0.00
# max       39039582.05      1.00            0.00

# %%
df.head(5)
# Out:
#    step      type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT  9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT  1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER   181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT   181.00   C840083671         181.00            0.00
# 4     1   PAYMENT 11668.14  C2048537720       41554.00        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155            0.00            0.00     0.00            0.00
# 1  M2044282225            0.00            0.00     0.00            0.00
# 2   C553264065            0.00          181.00     1.00            0.00
# 3    C38997010        21182.00        21363.00     1.00            0.00
# 4  M1230701703            0.00            0.00     0.00            0.00

# %% [markdown]
# # **Data visualization**

# %% [markdown]
# # 📊 1️⃣ Histogram
# understand the distribution of numerical data.

# %%
# to check transaction amount
# Helps see how transaction amounts are spread and if fraud transactions have unusual amounts.
plt.figure(figsize=(6,4))
plt.hist(df['amount'],bins=20,color='red')
plt.xlabel('amount')
plt.ylabel('frequency')
plt.title('transaction amount')
plt.show()

# %% [markdown]
# # check With numerical data not with categorical data

# %%
#old balance org
plt.figure(figsize=(6,4))
plt.hist(df['oldbalanceOrg'],bins=20,color='blue')
plt.xlabel('amount')
plt.ylabel('frequency')
plt.title('old balance')
plt.show()

# %%
#new balance org
plt.figure(figsize=(6,4))
plt.hist(df['newbalanceOrig'],bins=20,color='violet')
plt.xlabel('amount')
plt.ylabel('frequency')
plt.title('new balance')
plt.show()

# %%
#old balance dest
plt.figure(figsize=(6,4))
plt.hist(df['oldbalanceDest'],bins=20,color='yellow',edgecolor='black')
plt.xlabel('amount')
plt.ylabel('frequency')
plt.title('old balance dest')
plt.show()

# %%
#new balance dest
plt.figure(figsize=(6,4))
plt.hist(df['newbalanceDest'],bins=20,color='green',edgecolor='black')
plt.xlabel('amount')
plt.ylabel('frequency')
plt.title('old balance')
plt.show()

# %% [markdown]
# # **step2:box plot**
# 🚫A box plot is a graphical representation of data distribution that helps in detecting outliers.

# %%
#amount
plt.figure(figsize=(6,4))
plt.boxplot(df['amount'])
plt.xlabel('amount')
plt.title('Boxplot of Amount')
plt.show()

# %%
#to check whether outliers should remove or to keep
print(df['amount'].max())
print(df['amount'].min())
print(df['amount'].describe())
# Out:
# 10000000.0
# 0.32
# count     165438.00
# mean      179350.47
# std       336032.65
# min            0.32
# 25%        11410.16
# 50%        63765.80
# 75%       224848.46
# max     10000000.00
# Name: amount, dtype: float64

# %% [markdown]
# ![image.png]()

# %% [markdown]
# # some are very high so check boundaries

# %%
q1 = df['amount'].quantile(0.25)
q3 = df['amount'].quantile(0.75)#use formula
iqr=q3-q1
upper=q3+1.5*iqr
lower=q1-1.5*iqr
outliers = df[(df['amount'] < lower) | (df['amount'] > upper)]

print(outliers[['amount', 'isFraud']].value_counts())
# Out:
# amount       isFraud
# 10000000.00  1.00       2
# 1096187.24   1.00       2
# 1041647.06   1.00       2
# 2930418.44   1.00       2
# 963532.14    1.00       2
#                        ..
# 722055.29    0.00       1
# 722077.46    0.00       1
# 722161.86    0.00       1
# 722193.34    0.00       1
# 934479.64    0.00       1
# Name: count, Length: 10066, dtype: int64

# %%
fraud_outliers = outliers[outliers['isFraud'] == 1]
print(fraud_outliers[['amount', 'isFraud']].value_counts())
# Out:
# amount       isFraud
# 556218.01    1.00       2
# 963532.14    1.00       2
# 1041647.06   1.00       2
# 1096187.24   1.00       2
# 1154353.99   1.00       2
# 1277212.77   1.00       2
# 2539898.07   1.00       2
# 2662734.59   1.00       2
# 2930418.44   1.00       2
# 3964129.99   1.00       2
# 5460002.91   1.00       2
# 10000000.00  1.00       2
# 994453.20    1.00       1
# 1078013.76   1.00       1
# 1933920.80   1.00       1
# Name: count, dtype: int64

# %%
outliers = df[(df['amount'] > upper) | (df['amount'] < lower)] # Get all transactions above the upper bound
print(outliers[['amount', 'isFraud']].value_counts())  # Count fraud and non-fraud outliers
# Out:
# amount       isFraud
# 10000000.00  1.00       2
# 1096187.24   1.00       2
# 1041647.06   1.00       2
# 2930418.44   1.00       2
# 963532.14    1.00       2
#                        ..
# 722055.29    0.00       1
# 722077.46    0.00       1
# 722161.86    0.00       1
# 722193.34    0.00       1
# 934479.64    0.00       1
# Name: count, Length: 10066, dtype: int64

# %% [markdown]
# ![image.png]()

# %%
#negative ignore it
outliers = df[(df['amount'] > upper) & (df['amount'] >= 0)]
print(len(outliers))
print(outliers[['amount', 'isFraud']].value_counts())
# Out:
# 10078
# amount       isFraud
# 10000000.00  1.00       2
# 1096187.24   1.00       2
# 1041647.06   1.00       2
# 2930418.44   1.00       2
# 963532.14    1.00       2
#                        ..
# 722055.29    0.00       1
# 722077.46    0.00       1
# 722161.86    0.00       1
# 722193.34    0.00       1
# 934479.64    0.00       1
# Name: count, Length: 10066, dtype: int64

# %%
fraud_outliers = outliers[outliers['isFraud'] == 1]
non_fraud_outliers = outliers[outliers['isFraud'] == 0]
print(len(fraud_outliers))
print(len(non_fraud_outliers))
# Out:
# 27
# 10051

# %%
df_no_outliers = df[(df['amount'] >= lower) & (df['amount'] <= upper)]
print(len(df))
print(len(df_no_outliers))#data size reduced
# Out:
# 165438
# 155360

# %% [markdown]
# # **step3:scatter plot**
# A scatter plot is used to display the relationship between two numerical variables. It helps in identifying patterns, trends, and correlations between data points.

# %%
#amount vs fraud
#to check how much amount as fraud
plt.figure(figsize=(6,4))
plt.scatter(df['amount'],df['isFraud'],c=df['isFraud'].map({0: 'yellow', 1: 'darkblue'}))
plt.xlabel('amount')
plt.ylabel('fraud (1) / non fraud(0)')
plt.title('amount vs fraud')
plt.show()

# %%
#amount vs new balance
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['amount'], y=df['newbalanceOrig'], hue=df['isFraud'], palette={0:"hotpink",1:'green'})
plt.xlabel('Transaction Amount')
plt.ylabel('New Balance')
plt.title('Amount vs. New Balance')
plt.show()

# %% [markdown]
# ✅ What does it show?
#
# How much balance is left after a transaction for the sender (origin account).
# Helps detect if fraudsters empty their accounts after fraudulent transactions.

# %%
df.head(1)
# Out:
#    step     type  amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT 9839.64  C1231006815      170136.00       160296.36
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155            0.00            0.00     0.00            0.00

# %%
#amount vs old balance orig
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['amount'],y=df['oldbalanceOrg'],hue=df['isFraud'],palette={0:'purple',1:'grey'})
plt.xlabel('amount')
plt.ylabel('old balance')
plt.title('amount vs old balance')
plt.show()

# %% [markdown]
# ✅ If fraud transactions mostly cluster near oldbalanceOrig = 0, it means fraudsters start with little to no money.
# ✅ If fraud transactions happen across high balances, it may indicate fraudsters with large funds trying to hide fraudulent activity.

# %%
#amount vs new balance dest
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['amount'],y=df['newbalanceDest'],hue=df['isFraud'],palette={0:'deeppink',1:'indigo'})
plt.xlabel('amount')
plt.ylabel('new balance')
plt.title('amount vs new balance')
plt.show()

# %%
#oldbalancedest
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['amount'],y=df['oldbalanceDest'],hue=df['isFraud'],palette={0:'darkred',1:'black'})
plt.xlabel('amount')
plt.ylabel('old balance')
plt.title('amount vs old balancedest')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['step'],y=df['amount'],hue=df['isFraud'],palette={0:'darkgreen',1:'orangered'})
plt.xlabel('step')
plt.ylabel('amount')
plt.title('step vs amount')
plt.show()

# %% [markdown]
# # **📊 Bar Charts in Data Visualization**

# %% [markdown]
# **🎯 Where to Use Bar Charts in Your PaySim Project?**
# 📌 Fraud vs. Non-Fraud Counts → To show how many transactions are fraud.
# 📌 Transaction Types → To compare different types of transactions.
# 📌 Fraud Rate by Transaction Type → To find the most fraud-prone transactions.

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=df['isFraud'].value_counts().index, y=df['isFraud'].value_counts().values, palette=['blue', 'red'])
plt.xlabel('fraud')
plt.ylabel('amount')
plt.title('fraud vs non fraud')
plt.show()
# Out:
# <ipython-input-48-7d2117c3e4a0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['isFraud'].value_counts().index, y=df['isFraud'].value_counts().values, palette=['blue', 'red'])

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=df['type'],y=df['isFraud'],color='black')
plt.xlabel('type')
plt.ylabel('fraud')
plt.title('type vs fraud')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=df['step'],y=df['amount'],color='green')
plt.xlabel('step')
plt.ylabel('amount')
plt.title('step vs amount')
plt.show()

# %% [markdown]
# # **📌 Understanding Line Charts**
# **📍 When to Use a Line Chart?**
# ✅ If you have time-based data (e.g., fraud cases per day, transactions over time)
# ✅ If you want to see trends or patterns (e.g., is fraud increasing or decreasing?)
# ✅ If you want to compare multiple trends (e.g., fraud vs non-fraud transactions over time)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#x axis....time based data
#y axis....numeric values like amount

# %%
df.head(1)
# Out:
#    step     type  amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT 9839.64  C1231006815      170136.00       160296.36
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155            0.00            0.00     0.00            0.00

# %%
#tansaction index vs fraud
plt.figure(figsize=(6,4))
sns.lineplot(x=df.index,y=df['isFraud'],color='darkblue')
plt.xlabel('transaction')
plt.ylabel('fraud(0=no,1=yes)')
plt.title('transaction vs fraud')
plt.grid(True)
plt.show()

# %%
#type vs fraud
plt.figure(figsize=(6,4))
sns.lineplot(x=df['type'],y=df['isFraud'],color='c')
plt.xlabel('type')
plt.ylabel('fraud')
plt.title('type vs fraud')
plt.show()

# %%
#type vs fraud
plt.figure(figsize=(6,4))
sns.lineplot(x=df['amount'],y=df['isFraud'],color='cadetblue')
plt.xlabel('amount')
plt.ylabel('fraud')
plt.title('amount vs fraud')
plt.show()

# %%
#oldbalance vs fraud
plt.figure(figsize=(6,4))
sns.lineplot(x=df['oldbalanceOrg'],y=df['isFraud'],color='c')
plt.xlabel('balance')
plt.ylabel('fraud')
plt.title('t vs fraud')
plt.show()

# %% [markdown]
# # **📌 Pie Chart in Matplotlib**
# A pie chart is used to represent proportions of different categories in a dataset. It helps in visualizing how a whole is divided into parts.

# %% [markdown]
# # 1️⃣ When to Use a Pie Chart?
# ✔ When you want to show the percentage/proportion of categories in a dataset.
# ✔ When the sum of all categories forms a meaningful whole (e.g., total transactions, total fraud cases, etc.).
# ✔ When there are few categories (Too many categories make it unreadable).

# %%
#doubt(later)

# %% [markdown]
# # **✨ Data Preprocessing for PaySim Fraud Detection ML Project**

# %% [markdown]
# # **📌 Step 1:Feature Scaling **
